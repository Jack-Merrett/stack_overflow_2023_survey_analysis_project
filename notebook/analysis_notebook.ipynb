# %% [markdown]
# # Stack Overflow Analysis Project 🧐

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project we will be using our analytical skill to answer a few questions using the data from the Stack Overflow 2023 survey.

# %% [markdown]
# **Questions**:
# 1. At what companies do developers get paid the most?
# 2. How much does remote working matter to employees?
# 3. How does coding experience affect the level of pay?
# 4. What's the most popular method of learning to code?
# 5. Are the chances of getting a job higher as a developer if you have a master's degree?

# %% [markdown]
# ## Data Set 📊 and Libraries 📚

# %%
# import the basic data sets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# call in the libraries

df = pd.read_csv('../data/survey_results_public.csv')
df2 = pd.read_csv('../data/survey_results_schema.csv')

# %% [markdown]
# ### Looking at both data sets

# %%
pd.set_option('display.max_columns',84)
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
# This Data Set doesn't seem useful to me. We will disreguard it for now. 
df2.head()
# Out:
#       qid     qname                                           question  \
# 0   QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12  MetaInfo                                  Browser Meta Info
# 2  QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# 3  QID312      Q120
# 4    QID1        S1  <span style="font-size:22px; font-family: aria...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    DB       TB

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.dtypes
# Out:
# ResponseId                               int64
# Q120                                    object
# MainBranch                              object
# Age                                     object
# Employment                              object
# RemoteWork                              object
# CodingActivities                        object
# EdLevel                                 object
# LearnCode                               object
# LearnCodeOnline                         object
# LearnCodeCoursesCert                    object
# YearsCode                               object
# YearsCodePro                            object
# DevType                                 object
# OrgSize                                 object
# PurchaseInfluence                       object
# TechList                                object
# BuyNewTool                              object
# Country                                 object
# Currency                                object
# ...

# %%
# Check for Null Values. 
pd.set_option('display.max_rows',84) #So we can see all the columns
df.isna().sum()
# Out:
# ResponseId                                 0
# Q120                                       0
# MainBranch                                 0
# Age                                        0
# Employment                              1286
# RemoteWork                             15374
# CodingActivities                       15420
# EdLevel                                 1211
# LearnCode                               1521
# LearnCodeOnline                        19100
# LearnCodeCoursesCert                   52108
# YearsCode                               1749
# YearsCodePro                           23048
# DevType                                12312
# OrgSize                                24141
# PurchaseInfluence                      24220
# TechList                               28333
# BuyNewTool                              6175
# Country                                 1211
# Currency                               23850
# CompTotal                              40959
# ...

# %% [markdown]
# ## Data cleaning 🧴 🧼

# %%
# Drop duplicate rows (if there are any)
df.drop_duplicates()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %% [markdown]
# ### Replacing Null Values

# %% [markdown]
# Since a we aren't doing a whole lot of intence data cleaning, we are going to replace the null values with 'Unknown'.

# %%
df.fillna("Unknown", inplace = True) # replaceing all null values

# %%
df.head() # Checking to see if the data set worked.
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                            Unknown
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                               Unknown
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.isna().sum() # There are no longer null values.
# Out:
# ResponseId                             0
# Q120                                   0
# MainBranch                             0
# Age                                    0
# Employment                             0
# RemoteWork                             0
# CodingActivities                       0
# EdLevel                                0
# LearnCode                              0
# LearnCodeOnline                        0
# LearnCodeCoursesCert                   0
# YearsCode                              0
# YearsCodePro                           0
# DevType                                0
# OrgSize                                0
# PurchaseInfluence                      0
# TechList                               0
# BuyNewTool                             0
# Country                                0
# Currency                               0
# CompTotal                              0
# LanguageHaveWorkedWith                 0
# LanguageWantToWorkWith                 0
# ...
